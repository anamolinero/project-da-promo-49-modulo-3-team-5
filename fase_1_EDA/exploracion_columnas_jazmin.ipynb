# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("hr_raw_data.csv", index_col = 0)

df.head(3)
# Out:
#   age attrition businesstravel    dailyrate                department  \
# 0  51        No            NaN  2015.722222                       NaN
# 1  52        No            NaN  2063.388889                       NaN
# 2  42        No  travel_rarely  1984.253968   Research & Development
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
#
#    employeenumber  environmentsatisfaction  gender  hourlyrate  \
# 0               1                        1       0         NaN
# 1               2                        3       0         NaN
# 2               3                        3       0         NaN
#
#    jobinvolvement  joblevel              jobrole  jobsatisfaction  \
# 0               3         5   resEArch DIREcToR                 3
# ...

# %%
mover = df.pop('employeenumber')  # Eliminar y guardar la columna
df.insert(0, 'employeenumber', mover)

# %%
df.head(10)
# Out:
#    employeenumber age attrition     businesstravel    dailyrate  \
# 0               1  51        No                NaN  2015.722222
# 1               2  52        No                NaN  2063.388889
# 2               3  42        No      travel_rarely  1984.253968
# 3               4  47        No      travel_rarely  1771.404762
# 4               5  46        No                NaN  1582.771346
# 5               6  48        No                NaN  1771.920635
# 6               7  59        No                NaN  1032.487286
# 7               8  42        No      travel_rarely   556.256661
# 8               9  41        No                NaN  1712.182540
# 9              10  41        No  travel_frequently  1973.984127
#
#                  department  distancefromhome  education    educationfield  \
# 0                       NaN                 6          3               NaN
# 1                       NaN                 1          4     Life Sciences
# ...

# %%
# Supongamos que tienes un DataFrame llamado 'df'
# ... (código para cargar o crear tu DataFrame) ...

# Identificar los números duplicados
duplicados = df[df['employeenumber'].duplicated()]

# Extraer solo la columna 'employeenumber' de los duplicados
numeros_duplicados = duplicados['employeenumber']

# Imprimir los números duplicados
print(numeros_duplicados)

# si solo quieres los valores unicos de los duplicados.
print(numeros_duplicados.unique())

# si quieres contar los duplicados.
print(numeros_duplicados.value_counts())
# Out:
# 1614     178
# 1615     853
# 1616     112
# 1617     159
# 1618     969
#         ...
# 1673     824
# 1674    1087
# 1675     528
# 1676      76
# 1677     401
# Name: employeenumber, Length: 64, dtype: int64
# [ 178  853  112  159  969  633 1339  932 1179  168  271 1349  672 1158
#  1393  191  300  864  878  352  293 1402 1212 1567 1568 1056  532 1048
#   304 1525  203 1474 1235 1532  828  108 1030  526   61  564 1060 1243
#     9 1569 1245 1499  663 1370 1326  644 1477 1324  958 1268  755  977
#  1342 1608  369  824 1087  528   76  401]
# employeenumber
# 178     1
# 853     1
# 112     1
# 159     1
# 969     1
#        ..
# 824     1
# 1087    1
# 528     1
# 76      1
# 401     1
# Name: count, Length: 64, dtype: int64

# %%
df.loc[[852, 1615]]
# Out:
#       employeenumber age attrition businesstravel  dailyrate  \
# 852              853  59        No  travel_rarely  290.03551
# 1615             853  59        No  travel_rarely  290.03551
#
#              department  distancefromhome  education educationfield  \
# 852    Human Resources                  6          2        Medical
# 1615   Human Resources                  6          2        Medical
#
#       employeecount  environmentsatisfaction  gender  hourlyrate  \
# 852               1                        2       0         NaN
# 1615              1                        2       0         NaN
#
#       jobinvolvement  joblevel            jobrole  jobsatisfaction  \
# 852                3         1   humAN resoURCEs                 3
# 1615               3         1   humAN resoURCEs                 3
#
#      maritalstatus monthlyincome monthlyrate  numcompaniesworked over18  \
# 852        Married      2342,59$    6090,75$                   8      Y
# ...

# %%
df.loc[[177, 1614]]
# Out:
#       employeenumber age attrition businesstravel    dailyrate department  \
# 177              178  35        No            NaN  1032.487286        NaN
# 1614             178  35        No            NaN  1032.487286        NaN
#
#       distancefromhome  education educationfield  employeecount  \
# 177                 18          5  Life Sciences              1
# 1614                18          5  Life Sciences              1
#
#       environmentsatisfaction  gender  hourlyrate  jobinvolvement  joblevel  \
# 177                         2       0         NaN               3         3
# 1614                        2       0         NaN               3         3
#
#                 jobrole  jobsatisfaction maritalstatus monthlyincome  \
# 177    sAlES eXeCuTIVe                 1       Married      8339,32$
# 1614   sAlES eXeCuTIVe                 1       Married      8339,32$
#
#      monthlyrate  numcompaniesworked over18 overtime  percentsalaryhike  \
# ...

# %%
def eliminar_duplicados_empleado(df):

    df2 = df.drop_duplicates(subset='employeenumber', keep='first')
    return df2

# %%
df2 = eliminar_duplicados_empleado(df)

# %%
df2['employeenumber'].duplicated().any()
# Out:
# np.False_

# %%
duplicados = df2[df2['employeenumber'].duplicated()]

# Extraer solo la columna 'employeenumber' de los duplicados
numeros_duplicados = duplicados['employeenumber']

# Imprimir los números duplicados
print(numeros_duplicados)

# si solo quieres los valores unicos de los duplicados.
print(numeros_duplicados.unique())

# si quieres contar los duplicados.
print(numeros_duplicados.value_counts())
# Out:
# Series([], Name: employeenumber, dtype: int64)
# []
# Series([], Name: count, dtype: int64)

# %%
df2.loc[[1614]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df2.loc[[1614]]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# ...

# %%
df2.tail()
# Out:
#       employeenumber age attrition businesstravel    dailyrate department  \
# 1609            1610  36       Yes  travel_rarely  1065.277778        NaN
# 1610            1611  45        No     non-travel   458.817460        NaN
# 1611            1612  39        No  travel_rarely  1032.487286        NaN
# 1612            1613  36        No     non-travel   556.256661        NaN
# 1613            1614  46        No            NaN  1118.928571        NaN
#
#       distancefromhome  education    educationfield  employeecount  \
# 1609                 3          1     Life Sciences              1
# 1610                 4          2               NaN              1
# 1611               -13          5               NaN              1
# 1612                 8          4  Technical Degree              1
# 1613                 7          2           Medical              1
#
#       environmentsatisfaction  gender  hourlyrate  jobinvolvement  joblevel  \
# ...

# %% [markdown]
# 29. totalworkingyears
# 30. trainingtimeslastyear
# 31. worklifebalance
# 32. yearsatcompany
# 33. yearsincurrentrole
# 34. yearssincelastpromotion
# 35. yearswithcurrmanager
# 36. sameasmonthlyincome
# 37. datebirth
# 38. salary
# 39. roledepartament
# 40. numberchildren
# 41. remotework

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1614 entries, 0 to 1613
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   employeenumber            1614 non-null   int64
#  1   age                       1614 non-null   object
#  2   attrition                 1614 non-null   object
#  3   businesstravel            842 non-null    object
#  4   dailyrate                 1614 non-null   float64
#  5   department                302 non-null    object
#  6   distancefromhome          1614 non-null   int64
#  7   education                 1614 non-null   int64
#  8   educationfield            869 non-null    object
#  9   employeecount             1614 non-null   int64
#  10  environmentsatisfaction   1614 non-null   int64
#  11  gender                    1614 non-null   int64
#  12  hourlyrate                404 non-null    float64
#  13  jobinvolvement            1614 non-null   int64
# ...

# %% [markdown]
# 29. totalworkingyears

# %%
df2["totalworkingyears"].unique() #obj -, - nan
# Out:
# array([nan, '34,0', '22,0', '28,0', '20,0', '21,0', '33,0', '40,0',
#        '18,0', '25,0', '15,0', '17,0', '26,0', '16,0', '24,0', '14,0',
#        '23,0', '27,0', '19,0', '11,0', '38,0', '37,0', '13,0', '12,0',
#        '29,0', '10,0', '36,0', '35,0', '9,0', '31,0', '32,0', '8,0',
#        '7,0', '30,0', '6,0', '5,0', '4,0', '3,0', '2,0', '1,0', '0,0'],
#       dtype=object)

# %% [markdown]
# 30. trainingtimeslastyear

# %%
df2["trainingtimeslastyear"].unique() #int
# Out:
# array([5, 3, 2, 0, 1, 4, 6])

# %% [markdown]
# 31. worklifebalance

# %%
df2["worklifebalance"].unique() #obj - , - nan
# Out:
# array(['3,0', nan, '2,0', '4,0', '1,0'], dtype=object)

# %% [markdown]
# 32. yearsatcompany

# %%
df2["yearsatcompany"].unique() #int
# Out:
# array([20, 33, 22, 19, 21, 18, 24, 31, 26, 16, 23, 15, 17, 32, 14, 13, 25,
#        12, 11, 37, 40, 36, 27, 29, 10,  9, 30,  8,  7, 34,  6,  5,  4,  2,
#         3,  1,  0])

# %% [markdown]
# 33. yearsincurrentrole

# %%
df2["yearsincurrentrole"].unique() #obj -,
# Out:
# array([nan, '13,0', '12,0', '11,0', '7,0', '6,0', '4,0', '3,0', '2,0',
#        '1,0', '0,0'], dtype=object)

# %% [markdown]
# 34. yearssincelastpromotion

# %%
df2["yearssincelastpromotion"].unique() #int
# Out:
# array([15, 11,  5,  2,  4,  7,  0,  1, 13, 14,  8, 12,  3,  6, 10,  9])

# %% [markdown]
# 35. yearswithcurrmanager

# %%
df2["yearswithcurrmanager"].unique() #int
# Out:
# array([15,  9,  6,  8,  7, 11, 10, 12,  4,  0,  5, 17,  2, 14,  1, 13,  3,
#        16])

# %% [markdown]
# 36. sameasmonthlyincome

# %%
df2["sameasmonthlyincome"].unique() #obj - $ - , nan, renamecolum
# Out:
# array(['16280,83$', nan, '14307,50$', '12783,92$', '14311,67$',
#        '8339,32$', '13829,17$', '15943,72$', '16644,17$', '15034,17$',
#        '16038,33$', '4492,84$', '8956,67$', '5167,50$', '3334,17$',
#        '8705,83$', '2675,00$', '8555,00$', '8729,17$', '3934,17$',
#        '3845,83$', '14132,50$', '8588,33$', '4505,00$', '4918,33$',
#        '4928,33$', '5538,33$', '11100,00$', '5572,50$', '11560,00$',
#        '15870,83$', '13345,83$', '8010,83$', '3588,33$', '14205,00$',
#        '4222,50$', '3076,67$', '2342,59$', '4789,17$', '8685,00$',
#        '5289,17$', '1956,67$', '10408,33$', '6683,33$', '7452,50$',
#        '16060,00$', '4647,50$', '2242,50$', '6169,17$', '7352,50$',
#        '2982,50$', '14815,83$', '15177,50$', '15991,67$', '15989,17$',
#        '8340,00$', '6656,67$', '5902,50$', '3935,83$', '2839,17$',
#        '2440,83$', '10025,83$', '12855,83$', '5135,00$', '4271,67$',
#        '8015,83$', '4175,00$', '15860,83$', '8666,67$', '2327,50$',
# ...

# %% [markdown]
# 37. datebirth

# %%
df2["datebirth"].unique() #int
# Out:
# array([1972, 1971, 1981, 1976, 1977, 1975, 1964, 1982, 1967, 1985, 1968,
#        1983, 1965, 1988, 1978, 1990, 1987, 1989, 1970, 1980, 1963, 1991,
#        1986, 1974, 1984, 1973, 1979, 1993, 1994, 1992, 1969, 1966, 1996,
#        1995, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005])

# %% [markdown]
# 38. salary

# %%
df2["salary"].unique() #obj - $ - , - nan, renamecolum
# Out:
# array(['195370,00$', '199990,00$', '192320,00$', '171690,00$', nan,
#        '100071,84$', '53914,11$', '165950,00$', '199730,00$',
#        '134020,00$', '132060,00$', '195450,00$', '180410,00$',
#        '192460,00$', '107480,00$', '167520,00$', '62010,00$',
#        '198450,00$', '40010,00$', '104470,00$', '191324,62$',
#        '160640,00$', '32100,00$', '102660,00$', '104750,00$', '61620,00$',
#        '47210,00$', '153407,07$', '28111,13$', '46150,00$', '169590,00$',
#        '54060,00$', '59020,00$', '108550,00$', '59140,00$', '66460,00$',
#        '139730,00$', '66870,00$', '47350,00$', '138720,00$', '190450,00$',
#        '96130,00$', '115100,00$', '170460,00$', '36920,00$', '198470,00$',
#        '23080,00$', '57470,00$', '104220,00$', '63470,00$', '23480,00$',
#        '30720,00$', '124900,00$', '80200,00$', '170680,00$', '89430,00$',
#        '192720,00$', '55770,00$', '26910,00$', '74030,00$', '88230,00$',
#        '35790,00$', '177790,00$', '182130,00$', '135770,00$',
# ...

# %% [markdown]
# 39. roledepartament

# %%
df2["roledepartament"].unique() #obj - nan - Mayus&minus - 2 columnas en una (la primera unir a jobrole)
# Out:
# array([nan, ' ManaGER  -  Research & Development ',
#        ' MANAger  -  Research & Development ',
#        ' heaLtHcArE repResENtATiVe  -  Research & Development ',
#        ' saLEs exEcutIVe  -  Sales ', ' Sales ExECuTIVe  -  Sales ',
#        ' heALthCArE RePResEntaTIVe  -  Research & Development ',
#        ' lABORAtOry tECHnIcIan  -  Research & Development ',
#        ' ManufactUrINg DiReCTOr  -  Research & Development ',
#        ' SaleS eXEcUtIVE  -  Sales ',
#        ' HEaLthcaRe rEprEsEnTAtiVe  -  Research & Development ',
#        ' rESeArCH sCientIST  -  Research & Development ',
#        ' healTHCAre rePREseNtATiVE  -  Research & Development ',
#        ' mANaGer  -  Research & Development ',
#        ' HEAltHCaRe REPreseNTatIve  -  Research & Development ',
#        ' SaLeS eXECUTivE  -  Sales ',
#        ' reSeARCH SCIEnTiST  -  Research & Development ',
#        ' ReSearch DiRecTOR  -  Research & Development ',
# ...

# %%
df2["jobrole"].unique()
# Out:
# array([' resEArch DIREcToR ', ' ManAGeR ', ' ManaGER ', ...,
#        ' sAlES ExECUTivE ', ' SaLes ExecUtIVe ',
#        ' mAnUfactURInG DiRECTOr '], shape=(1579,), dtype=object)

# %% [markdown]
# 40. numberchildren

# %%
df2["numberchildren"].unique() #nan
# Out:
# array([nan])

# %% [markdown]
# 41. remotework

# %%
df2["remotework"].unique() #obj - yes,1,true -1,false
# Out:
# array(['Yes', '1', 'False', '0', 'True'], dtype=object)

# %% [markdown]
# # Limpieza

# %%
columnas_a_modificar = ["totalworkingyears", "worklifebalance", "yearsincurrentrole"]  

for columna in columnas_a_modificar:
    if columna in df2.columns:
        df2[columna] = df2[columna].str.replace(",0", "")

df2.head()
# Out:
# C:\Users\InvitadoLaptop\AppData\Local\Temp\ipykernel_16856\1217843166.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[columna] = df2[columna].str.replace(",0", "")
#    employeenumber age attrition businesstravel    dailyrate  \
# 0               1  51        No            NaN  2015.722222
# 1               2  52        No            NaN  2063.388889
# 2               3  42        No  travel_rarely  1984.253968
# 3               4  47        No  travel_rarely  1771.404762
# 4               5  46        No            NaN  1582.771346
#
#                  department  distancefromhome  education    educationfield  \
# 0                       NaN                 6          3               NaN
# ...

# %%
df2["totalworkingyears"].unique()
# Out:
# array([nan, '34', '22', '28', '20', '21', '33', '40', '18', '25', '15',
#        '17', '26', '16', '24', '14', '23', '27', '19', '11', '38', '37',
#        '13', '12', '29', '10', '36', '35', '9', '31', '32', '8', '7',
#        '30', '6', '5', '4', '3', '2', '1', '0'], dtype=object)

# %%
columnas_a_modificar = ["sameasmonthlyincome", "salary"]  

for columna in columnas_a_modificar:
    if columna in df2.columns:
        df2[columna] = df2[columna].str.replace(",", ".")

df2.head()
# Out:
# C:\Users\InvitadoLaptop\AppData\Local\Temp\ipykernel_16856\2992581148.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[columna] = df2[columna].str.replace(",", ".")
#    employeenumber age attrition businesstravel    dailyrate  \
# 0               1  51        No            NaN  2015.722222
# 1               2  52        No            NaN  2063.388889
# 2               3  42        No  travel_rarely  1984.253968
# 3               4  47        No  travel_rarely  1771.404762
# 4               5  46        No            NaN  1582.771346
#
#                  department  distancefromhome  education    educationfield  \
# 0                       NaN                 6          3               NaN
# ...

# %%
columnas_a_modificar = ["sameasmonthlyincome", "salary"]  

for columna in columnas_a_modificar:
    if columna in df2.columns:
        df2[columna] = df2[columna].str.replace("$", "")

df2.head()
# Out:
# C:\Users\InvitadoLaptop\AppData\Local\Temp\ipykernel_16856\3591462210.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[columna] = df2[columna].str.replace("$", "")
#    employeenumber age attrition businesstravel    dailyrate  \
# 0               1  51        No            NaN  2015.722222
# 1               2  52        No            NaN  2063.388889
# 2               3  42        No  travel_rarely  1984.253968
# 3               4  47        No  travel_rarely  1771.404762
# 4               5  46        No            NaN  1582.771346
#
#                  department  distancefromhome  education    educationfield  \
# 0                       NaN                 6          3               NaN
# ...

# %%
df2["remotework"] = df2["remotework"].str.replace("1", "Yes").replace("True", "Yes").replace("0", "False")
# Out:
# C:\Users\InvitadoLaptop\AppData\Local\Temp\ipykernel_16856\2195361942.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["remotework"] = df2["remotework"].str.replace("1", "Yes").replace("True", "Yes").replace("0", "False")

# %%
df2["remotework"].unique()
# Out:
# array(['Yes', 'False'], dtype=object)

# %%
columnas_a_modificar = ["roledepartament", "jobrole"]  

for columna in columnas_a_modificar:
    if columna in df2.columns:
        df2[columna] = df2[columna].str.lower()

df2.head()
# Out:
# C:\Users\InvitadoLaptop\AppData\Local\Temp\ipykernel_16856\1904181372.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[columna] = df2[columna].str.lower()
#    employeenumber age attrition businesstravel    dailyrate  \
# 0               1  51        No            NaN  2015.722222
# 1               2  52        No            NaN  2063.388889
# 2               3  42        No  travel_rarely  1984.253968
# 3               4  47        No  travel_rarely  1771.404762
# 4               5  46        No            NaN  1582.771346
#
#                  department  distancefromhome  education    educationfield  \
# 0                       NaN                 6          3               NaN
# ...

# %%
df2[["jobrole2", "roledepartament2"]] = df2["roledepartament"].str.split("-", expand = True).get([0,1])

# comprobamos que se han creado correctamente las columnas
df2.head(2)
# Out:
# C:\Users\InvitadoLaptop\AppData\Local\Temp\ipykernel_16856\115688937.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[["jobrole2", "roledepartament2"]] = df2["roledepartament"].str.split("-", expand = True).get([0,1])
# C:\Users\InvitadoLaptop\AppData\Local\Temp\ipykernel_16856\115688937.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[["jobrole2", "roledepartament2"]] = df2["roledepartament"].str.split("-", expand = True).get([0,1])
# ...

# %%
df2.drop("roledepartament", axis=1, inplace=True)
# Out:
# C:\Users\InvitadoLaptop\AppData\Local\Temp\ipykernel_16856\3880045599.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop("roledepartament", axis=1, inplace=True)

# %%
df2.head(2)
# Out:
#    employeenumber age attrition businesstravel    dailyrate department  \
# 0               1  51        No            NaN  2015.722222        NaN
# 1               2  52        No            NaN  2063.388889        NaN
#
#    distancefromhome  education educationfield  employeecount  \
# 0                 6          3            NaN              1
# 1                 1          4  Life Sciences              1
#
#    environmentsatisfaction  gender  hourlyrate  jobinvolvement  joblevel  \
# 0                        1       0         NaN               3         5
# 1                        3       0         NaN               2         5
#
#                jobrole  jobsatisfaction maritalstatus monthlyincome  \
# 0   research director                 3           NaN     16280,83$
# 1             manager                 3           NaN           NaN
#
#   monthlyrate  numcompaniesworked over18 overtime  percentsalaryhike  \
# ...

# %%
mergeado_izq["density_p/km2"] = mergeado_izq["density_p/km2"].astype(int)

# %%
columnas_a_modificar = ["totalworkingyears", "worklifebalance", "yearsincurrentrole", "sameasmonthlyincome", "salary"]  

for columna in columnas_a_modificar:
    if columna in df2.columns:
        df2[columna] = df2[columna].astype(float)

df2.head()
# Out:
# C:\Users\InvitadoLaptop\AppData\Local\Temp\ipykernel_16856\4094892634.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[columna] = df2[columna].astype(float)
# C:\Users\InvitadoLaptop\AppData\Local\Temp\ipykernel_16856\4094892634.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[columna] = df2[columna].astype(float)
# C:\Users\InvitadoLaptop\AppData\Local\Temp\ipykernel_16856\4094892634.py:5: SettingWithCopyWarning:
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1614 entries, 0 to 1613
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   employeenumber            1614 non-null   int64
#  1   age                       1614 non-null   object
#  2   attrition                 1614 non-null   object
#  3   businesstravel            842 non-null    object
#  4   dailyrate                 1614 non-null   float64
#  5   department                302 non-null    object
#  6   distancefromhome          1614 non-null   int64
#  7   education                 1614 non-null   int64
#  8   educationfield            869 non-null    object
#  9   employeecount             1614 non-null   int64
#  10  environmentsatisfaction   1614 non-null   int64
#  11  gender                    1614 non-null   int64
#  12  hourlyrate                404 non-null    float64
#  13  jobinvolvement            1614 non-null   int64
# ...
