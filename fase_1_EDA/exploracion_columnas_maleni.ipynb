# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Usuario/Documents/Adalab49/Módulo 3/Proyecto_módulo 3/borrador_equipo5/hr_raw_data.csv", index_col=0)
df.head()
# Out:
#   age attrition businesstravel    dailyrate                department  \
# 0  51        No            NaN  2015.722222                       NaN
# 1  52        No            NaN  2063.388889                       NaN
# 2  42        No  travel_rarely  1984.253968   Research & Development
# 3  47        No  travel_rarely  1771.404762                       NaN
# 4  46        No            NaN  1582.771346                       NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# 1                 1          4     Life Sciences              1
# 2                 4          2  Technical Degree              1
# 3                 2          4           Medical              1
# 4                 3          3  Technical Degree              1
#
#    employeenumber  ...  yearsatcompany  yearsincurrentrole  \
# 0               1  ...              20                 NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1678 entries, 0 to 1677
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1678 non-null   object
#  1   attrition                 1678 non-null   object
#  2   businesstravel            877 non-null    object
#  3   dailyrate                 1678 non-null   float64
#  4   department                312 non-null    object
#  5   distancefromhome          1678 non-null   int64
#  6   education                 1678 non-null   int64
#  7   educationfield            904 non-null    object
#  8   employeecount             1678 non-null   int64
#  9   employeenumber            1678 non-null   int64
#  10  environmentsatisfaction   1678 non-null   int64
#  11  gender                    1678 non-null   int64
#  12  hourlyrate                411 non-null    float64
#  13  jobinvolvement            1678 non-null   int64
# ...

# %%
pd.set_option('display.max_columns', None) #para ver todas las columnas con scroll en el dataframe

# %%
#Hemos hecho este bucle para convertir todos los datos de las columnas en minusculas
# Lista de columnas a convertir en minúsculas
columnas_minus = ['department', 'educationfield', 'jobrole', 'maritalstatus']
# Bucle solo para esas columnas
for columna in columnas_minus:
    df[columna] = df[columna].str.lower()

# %%
df.head(10)
# Out:
#   age attrition     businesstravel    dailyrate                department  \
# 0  51        No                NaN  2015.722222                       NaN
# 1  52        No                NaN  2063.388889                       NaN
# 2  42        No      travel_rarely  1984.253968   research & development
# 3  47        No      travel_rarely  1771.404762                       NaN
# 4  46        No                NaN  1582.771346                       NaN
# 5  48        No                NaN  1771.920635   research & development
# 6  59        No                NaN  1032.487286                       NaN
# 7  42        No      travel_rarely   556.256661                       NaN
# 8  41        No                NaN  1712.182540                       NaN
# 9  41        No  travel_frequently  1973.984127                       NaN
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                 6          3               NaN              1
# ...

# %%
df['maritalstatus'].unique()
# Out:
# array([nan, 'married', 'divorced', 'single', 'marreid'], dtype=object)

# %%
df["maritalstatus"] = df["maritalstatus"].replace({"marreid": "married"}) # Aqui eliminamos los errores ortotipográficos

# %%
df["maritalstatus"].unique()
# Out:
# array([nan, 'married', 'divorced', 'single'], dtype=object)

# %% [markdown]
# 15. joblevel = : Nivel jerárquico del puesto del empleado -- > OK
#
#  - Ya es un INT no hace falta cambiarlo de type
#
#
# 16. jobrole = Función o rol específico del empleado. --> OK
#
#   - Cambiar todo a minúscula
#   - Ya es un object no hace falta cambiar el type
#
# 17. jobsatisfaction = Satisfacción general en el puesto. --> OK
#   - Ya sabemos que 1 es menos que 4
#   - No hace falta cambiar el type porque ya es un INT
#
# 18. maritalstatus =  Estado civil (e.g., Single, Married). -- OK
#   -  Eliminar los errores ortotipográficos, lo hemos hecho con este código:
#    df["maritalstatus"] = df["maritalstatus"].replace({"marreid": "married"})
#   - Hay valores únicos vacíos que los vamos a reemplazar por None para poder visualizarlos en SQL
#   - Ahora es object no hay que cambiar el type
#
# 19. monthlyincome = Ingreso mensual estimado en base al salario anual. -->
#   - Eliminar el simbolo del $ e incluirlos solo en el nombre de la columna: monthlyincome ($)
#   - Eliminar la segunda columna "same as monthly income" que tiene los mismo valores
#   - Hay valores únicos vacíos que los vamos a reemplazar por None para poder visualizarlos en SQL
#   - Cambiar a Float ahora es un object
#
# 20. monthlyrate = Tarifa mensual estimada en función de la tarifa diaria.
#   - Eliminar el simbolo del $ e incluirlos solo en el nombre de la columna: monthlyrate ($)
#   - Cambiar a Float ahora es un object
#
# 21. numcompaniesworked = Número de empresas previas en las que ha trabajado. --OK
#   - No hay ningún cambio que hacer
#   - Ya es un INT
#
# 22. over18 = No aparece en la leyenda -- OK
#   - Eliminar
#
# 23. overtime =  Indica si el empleado trabaja horas extras (Yes/No).
#   - Cambiar las celdas vacías NaN por None
#   - Ya es de tipo object
#
# 24. percentsalaryhike = Incremento porcentual en el salario.
#   - Incluirle el simbolo de % en el nombre de la columna: percentsalaryhike (%)
#   - Ya es INT
#
# 25. performancerating = Evaluación de desempeño en una escala numérica.
#   - Cambiar las celdas vacías por None
#   - Solo tenemos 3 y 4 como puntaje de evaluación del desempeño, podríamos definir una leyenda para saber su significado?
#   ej. 3 = Notable
#       4 = Destacado
#
#   - Cambiar a INT ahora es object
#
# 26. relationshipsatisfaction = Satisfacción con relaciones interpersonales en el trabajo.
#   - No haría ningún cambio, quizás solo ponerle una leyenda pero no tenemos el dato de la escala de valoración
#
# 27. standardhours = Clasificación de jornada (Full Time/Part Time).
#   - Hay valores únicos vacíos que los vamos a reemplazar por None para poder visualizarlos en SQL
#   - Cambiar todo a minúsculas
#   - El dato ya es un object
#
# 28. stockoptionlevel = Nivel de opciones sobre acciones asignadas.
#   - No le haría ningún cambio y ya es un INT
